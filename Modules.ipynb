# %% [markdown]
# # Modules- Chapter 8

# %% [markdown]
#  Functions If you need to perform that task multiple
# times throughout your program, you don’t need to
# type all the code for the same task again and again;
# you just call the function dedicated to handling that task, and the call
# tells Python to run the code inside the function.

# %%
# Basic one
def greeting():
    print("Hi, Nice to meet you")

greeting()
# Out:
# Hi, Nice to meet you

# %%
# Another example:
def greet(name):
    print(f'Hi {name.title()}, nice to meet you')
greet('mahana')
greet("Alireza")
# Out:
# Hi Mahana, nice to meet you
# Hi Alireza, nice to meet you

# %%
#Multiple arguments and parameters function

 # Positional argument
def make_shirt(name, sentence):
    print(f'The T-Shirt size is {name.title()},')
    print(f'Sentence on the Shirt: {sentence.title()}')

make_shirt('medium', 'I love Alireza from Mahana')

 #Keyword argument
make_shirt(sentence = "I hate Hossein from Mahana",name = "Xlarge")
# Out:
# The T-Shirt size is Medium,
# Sentence on the Shirt: I Love Alireza From Mahana
# The T-Shirt size is Xlarge,
# Sentence on the Shirt: I Hate Hossein From Mahana

# %%
# Defult Values
def describe_pet(pet_name,age, animal_type='dog'): #after defult value cannot add undefult value
    print(f"\nI have a {animal_type}.")
    print(f"My {animal_type}'s name is {pet_name.title()}.")
    print(age)
    
describe_pet('Max', 8)

# You can cjange the defult value :)
describe_pet ('Hossein',9, "hamester")
# Out:
# I have a dog.
# My dog's name is Max.
# 8
#
# I have a hamester.
# My hamester's name is Hossein.
# 9

# %%
# Return value

# %% [markdown]
# The value the
# function returns is called a return value. The return statement takes a value
# from inside a function and sends it back to the line that called the func
# tion.

# %%
def name (name,surname):
    full_name =(f"{name} {surname}")
    return full_name.title()
    
name('Hossein','Moein')
# Out:
# 'Hossein Moein'

# %%
#Making an Argument Optional
def get_formatted_name(first_name, last_name, middle_name=''):
     if middle_name:
        full_name = f"{first_name} {middle_name} {last_name}"
     else:
        full_name = f"{first_name} {last_name}"
     return full_name.title()
musician = get_formatted_name('jimi', 'hendrix')
print(musician)
musician = get_formatted_name('john', 'hooker', 'lee')
print(musician)
# Out:
# Jimi Hendrix
# John Lee Hooker

# %%
#Returning a Dictionary
def build_person(first_name, last_name):
     person = {'first': first_name, 'last': last_name}
     return person
musician = build_person('jimi', 'hendrix')
print(musician)
# Out:
# {'first': 'jimi', 'last': 'hendrix'}

# %%
def build_person(first_name, last_name, age=None):
    person = {'first': first_name, 'last': last_name}
    if age:
        person['age'] = age
    return person
musician = build_person('jimi', 'hendrix', age=27)
print(musician)
# Out:
# {'first': 'jimi', 'last': 'hendrix', 'age': 27}

# %%
#Passing an Arbitrary Number of Arguments
def make_pizza(*toppings):
    """Print the list of toppings that have been requested."""
    print(toppings)
make_pizza('pepperoni')
make_pizza('mushrooms', 'green peppers', 'extra cheese')
# Out:
# ('pepperoni',)
# ('mushrooms', 'green peppers', 'extra cheese')

# %%
#Using Arbitrary Keyword Arguments # any keywords you want add
def build_profile(first, last, **user_info):

     user_info['first_name'] = first
     user_info['last_name'] = last
     return user_info
user_profile = build_profile('albert', 'einstein',
                             location='princeton',
                             field='physics')
print(user_profile)
# Out:
# {'location': 'princeton', 'field': 'physics', 'first_name': 'albert', 'last_name': 'einstein'}

# %% [markdown]
# ## Modules

# %% [markdown]
# Storing Your Functions in Modules
# One advantage of functions is the way they separate blocks of code from
# your main program. When you use descriptive names for your functions,
# your programs become much easier to follow. You can go a step further by
# storing your functions in a separate file called a module and then importing
# that module into your main program.

# %%
# first step mske a function
def make_pizza(size, *toppings,**moreinfo):
    print(f"\nMaking a {size}-inch pizza with the following toppings:")
    for topping in toppings:
        print(f"- {topping}")
    print(f'Extra needs include:')
    for key, value in moreinfo.items():  # ← Loop through items
        print(f"{key}: {value}")

# %%
# first step retrieve the module with import filename
import pizza

#second step call the function you need in the file "filname.functionname"
pizza.make_pizza(16,'mushrooms', 'green peppers', 'extra cheese',beverage = "Soda")
# Out:
# Making a 16-inch pizza with the following toppings:
# - mushrooms
# - green peppers
# - extra cheese
# Extra needs include: {'beverage': 'Soda'}

# %%
# another way
from pizza import make_pizza
make_pizza(14,'Mushroom',Desert = "Gele")
# Out:
# Making a 14-inch pizza with the following toppings:
# - Mushroom
# Extra needs include: {'Desert': 'Gele'}

# %%
from pizza import make_pizza as mp
mp(14,'Mushroom','Meet',Drink = "Malt ")
# Out:
# Making a 14-inch pizza with the following toppings:
# - Mushroom
# - Meet
# Extra needs include: {'Drink': 'Malt '}
